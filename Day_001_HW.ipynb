# %% [markdown]
# ## 作業一
#
# 挑選資料： [Histopathologic Cancer Detection](https://www.kaggle.com/c/histopathologic-cancer-detection/overview)
#
# 1. 你選的這組資料為何重要
#
# &emsp; 這組資料的重要性在於如何從圖片辨識輔助醫師判斷癌細胞擴散的風險，增加醫療的精準性得以挽救病人性命。
#
# 2. 資料從何而來
#
# &emsp; 這組資料是 *PachCamelyon(PCam)* 提供，擁有組織快篩的圖片。
#
# 3. 蒐集而來的資料型態為何
#
# &emsp; 資料為image的形式（非結構化資料）。
#
# 4. 這組資料想解決的問題如何評估
#
# &emsp; 這組資料最重要的評估指標是 **AUC & ROC** ，辨識越精準越好。

# %% [markdown]
# ## 作業二
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# &emsp; 核心問題在 **「降低空車時間，提高載客率」**，藉此提升業績。故我的假設為分析資料，並預測可能上車地點與時間，規劃載客最佳路線，減少空車時間、油耗等成本。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# &emsp; 我覺得資料要有每個司機載客的出發、結束地點、載客時間、金額等，蒐集資料則直接與司機的跳錶、GPS、叫車系統APP串接，直接由司機提供資料。
#
# 3. 蒐集而來的資料型態為何
#
# &emsp; 蒐集而來的資料型態有時間(date)、地點(類別資料)、金額(連續型資料)等
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# &emsp; 模型指標為準確度Accuracy

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return
        - mse: MSE
    """
    mse = sum((y - yp) ** 2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 277.096
# The Mean absolute error is 13.323
